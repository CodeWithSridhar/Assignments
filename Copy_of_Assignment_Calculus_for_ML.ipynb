# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeWithSridhar/Assignments/blob/main/Copy_of_Assignment_Calculus_for_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Complete these problems by hand in a piece of paper and then upload in a text cell.**

# %% [markdown]
# # Problem 1

# %% [markdown]
# Find the tangent line to $ f(x) = 4\sqrt[]{2x} + 6e^{2-x}$ at x=2.

# %% [markdown]
# ![q1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Problem 2

# %% [markdown]
# ![Screenshot 2020-11-17 at 6.43.18 PM.png](data:image/png;base64,...)

# %% [markdown]
# How many widgets should they try to sell in order to maximize their profit?

# %% [markdown]
# ![photo_2021-08-15_15-09-08.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Problem 3

# %% [markdown]
# Find the area bounded by the curves

# %% [markdown]
# ![Screenshot 2020-11-17 at 6.45.20 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![photo_2021-08-15_15-09-22.jpg](data:image/jpeg;base64,...)
